# %%
import pandas as pd
import sqlalchemy
import psycopg2
from sqlalchemy import create_engine

# %%
df = pd.read_csv('C:/Projects/Bike_share_project/bike_share_yr_0.csv')
df1 = pd.read_csv('C:/Projects/Bike_share_project/bike_share_yr_1.csv')
df2 = pd.read_csv('C:/Projects/Bike_share_project/cost_table.csv')

# %%
df.info()
df1.info()
df2.info()

# %%
df.describe()
df1.describe()
df2.describe()

# %%
df2.columns = df2.columns.str.lower()

# %%
df.duplicated().sum()
df1.duplicated().sum()
df2.duplicated().sum()
# Out:
# np.int64(0)

# %%
engine_psql = create_engine('postgresql+psycopg2://postgres:12345678@localhost:5432/bike_share_db')

try:
        engine_psql
        print('Success')
except:
        print('Unable to connect')
# Out:
# Success

# %%
df.to_sql(name='bike_share_yr_0', con= engine_psql, if_exists = 'append', index=False)
df1.to_sql(name='bike_share_yr_1', con= engine_psql, if_exists = 'append', index=False)
df2.to_sql(name='cost_table', con= engine_psql, if_exists = 'append', index=False)
# Out:
# 2
